# %% [markdown]
# <a href="https://colab.research.google.com/github/Umeshb21/Online-Payment-Fraud-Detection-/blob/main/Online_Payment_Fraud_Detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %%
df=pd.read_csv('/content/PS_20174392719_1491204439457_log.csv')

# %%
df.head()
# Out:
#    step      type    amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 0     1   PAYMENT   9839.64  C1231006815       170136.0       160296.36
# 1     1   PAYMENT   1864.28  C1666544295        21249.0        19384.72
# 2     1  TRANSFER    181.00  C1305486145          181.0            0.00
# 3     1  CASH_OUT    181.00   C840083671          181.0            0.00
# 4     1   PAYMENT  11668.14  C2048537720        41554.0        29885.86
#
#       nameDest  oldbalanceDest  newbalanceDest  isFraud  isFlaggedFraud
# 0  M1979787155             0.0             0.0      0.0             0.0
# 1  M2044282225             0.0             0.0      0.0             0.0
# 2   C553264065             0.0             0.0      1.0             0.0
# 3    C38997010         21182.0             0.0      1.0             0.0
# 4  M1230701703             0.0             0.0      0.0             0.0

# %%
df.isnull().sum()
# Out:
# step              0
# type              0
# amount            0
# nameOrig          0
# oldbalanceOrg     1
# newbalanceOrig    1
# nameDest          1
# oldbalanceDest    1
# newbalanceDest    1
# isFraud           1
# isFlaggedFraud    1
# dtype: int64

# %%
df.shape
# Out:
# (600612, 11)

# %%
df.type.value_counts()
# Out:
# type
# CASH_OUT    212996
# PAYMENT     203841
# CASH_IN     130174
# TRANSFER     48980
# DEBIT         4621
# Name: count, dtype: int64

# %%
type=df['type'].value_counts()

# %%
transactions=type.index

# %%
quantity=type.values

# %%
import plotly.express as px
px.pie(df,values=quantity,names=transactions,hole=0.4,title="Distribution of Transaction Type")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df=df.dropna()

# %%
df
# Out:
#         step      type     amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 0          1   PAYMENT    9839.64  C1231006815      170136.00       160296.36
# 1          1   PAYMENT    1864.28  C1666544295       21249.00        19384.72
# 2          1  TRANSFER     181.00  C1305486145         181.00            0.00
# 3          1  CASH_OUT     181.00   C840083671         181.00            0.00
# 4          1   PAYMENT   11668.14  C2048537720       41554.00        29885.86
# ...      ...       ...        ...          ...            ...             ...
# 600606    34   CASH_IN  194908.51   C965555479     3482556.34      3677464.86
# 600607    34   CASH_IN   45847.60  C1680702984     3677464.86      3723312.46
# 600608    34   CASH_IN  246497.27  C1281812381     3723312.46      3969809.72
# 600609    34   CASH_IN  168675.64   C194869336     3969809.72      4138485.36
# 600610    34   CASH_IN   42658.19  C1533591985     4138485.36      4181143.56
#
# ...

# %%
df['isFraud']=df['isFraud'].map({0:'No Fraud',1:'Fraud'})
# Out:
# <ipython-input-14-2bc703e4985e>:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df
# Out:
#         step      type     amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 0          1   PAYMENT    9839.64  C1231006815      170136.00       160296.36
# 1          1   PAYMENT    1864.28  C1666544295       21249.00        19384.72
# 2          1  TRANSFER     181.00  C1305486145         181.00            0.00
# 3          1  CASH_OUT     181.00   C840083671         181.00            0.00
# 4          1   PAYMENT   11668.14  C2048537720       41554.00        29885.86
# ...      ...       ...        ...          ...            ...             ...
# 600606    34   CASH_IN  194908.51   C965555479     3482556.34      3677464.86
# 600607    34   CASH_IN   45847.60  C1680702984     3677464.86      3723312.46
# 600608    34   CASH_IN  246497.27  C1281812381     3723312.46      3969809.72
# 600609    34   CASH_IN  168675.64   C194869336     3969809.72      4138485.36
# 600610    34   CASH_IN   42658.19  C1533591985     4138485.36      4181143.56
#
# ...

# %%
df['type'].unique()
# Out:
# array(['PAYMENT', 'TRANSFER', 'CASH_OUT', 'DEBIT', 'CASH_IN'],
#       dtype=object)

# %%
df['type'].value_counts()
# Out:
# type
# CASH_OUT    212996
# PAYMENT     203841
# CASH_IN     130173
# TRANSFER     48980
# DEBIT         4621
# Name: count, dtype: int64

# %%
df
# Out:
#         step      type     amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 0          1   PAYMENT    9839.64  C1231006815      170136.00       160296.36
# 1          1   PAYMENT    1864.28  C1666544295       21249.00        19384.72
# 2          1  TRANSFER     181.00  C1305486145         181.00            0.00
# 3          1  CASH_OUT     181.00   C840083671         181.00            0.00
# 4          1   PAYMENT   11668.14  C2048537720       41554.00        29885.86
# ...      ...       ...        ...          ...            ...             ...
# 600606    34   CASH_IN  194908.51   C965555479     3482556.34      3677464.86
# 600607    34   CASH_IN   45847.60  C1680702984     3677464.86      3723312.46
# 600608    34   CASH_IN  246497.27  C1281812381     3723312.46      3969809.72
# 600609    34   CASH_IN  168675.64   C194869336     3969809.72      4138485.36
# 600610    34   CASH_IN   42658.19  C1533591985     4138485.36      4181143.56
#
# ...

# %%
df['type']=df['type'].map({'PAYMENT':1, 'TRANSFER':4, 'CASH_OUT':2, 'DEBIT':5, 'CASH_IN':3})

# %%
df['type'].value_counts()
# Out:
# type
# 2    212996
# 1    203841
# 3    130173
# 4     48980
# 5      4621
# Name: count, dtype: int64

# %%
df
# Out:
#         step  type     amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 0          1     1    9839.64  C1231006815      170136.00       160296.36
# 1          1     1    1864.28  C1666544295       21249.00        19384.72
# 2          1     4     181.00  C1305486145         181.00            0.00
# 3          1     2     181.00   C840083671         181.00            0.00
# 4          1     1   11668.14  C2048537720       41554.00        29885.86
# ...      ...   ...        ...          ...            ...             ...
# 600606    34     3  194908.51   C965555479     3482556.34      3677464.86
# 600607    34     3   45847.60  C1680702984     3677464.86      3723312.46
# 600608    34     3  246497.27  C1281812381     3723312.46      3969809.72
# 600609    34     3  168675.64   C194869336     3969809.72      4138485.36
# 600610    34     3   42658.19  C1533591985     4138485.36      4181143.56
#
#            nameDest  oldbalanceDest  newbalanceDest   isFraud  isFlaggedFraud
# ...

# %%
df['type'].unique()
# Out:
# array([1, 4, 2, 5, 3])

# %%
df['type'].value_counts()
# Out:
# type
# 2    212996
# 1    203841
# 3    130173
# 4     48980
# 5      4621
# Name: count, dtype: int64

# %%
x=df[['type','amount','oldbalanceOrg','newbalanceOrig']]

# %%
y=df.iloc[:,-2]

# %%
y
# Out:
# 0         No Fraud
# 1         No Fraud
# 2            Fraud
# 3            Fraud
# 4         No Fraud
#             ...
# 600606    No Fraud
# 600607    No Fraud
# 600608    No Fraud
# 600609    No Fraud
# 600610    No Fraud
# Name: isFraud, Length: 600611, dtype: object

# %%
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.20,random_state=42)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
model=DecisionTreeClassifier()

# %%
model.fit(xtrain,ytrain)
# Out:
# DecisionTreeClassifier()

# %%
model.score(xtest,ytest)
# Out:
# 0.9994672127735738

# %%
model.predict([[4,180,181,10]])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning:
#
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# array(['Fraud'], dtype=object)

# %%
x
# Out:
#         type     amount  oldbalanceOrg  newbalanceOrig
# 0          1    9839.64      170136.00       160296.36
# 1          1    1864.28       21249.00        19384.72
# 2          4     181.00         181.00            0.00
# 3          2     181.00         181.00            0.00
# 4          1   11668.14       41554.00        29885.86
# ...      ...        ...            ...             ...
# 600606     3  194908.51     3482556.34      3677464.86
# 600607     3   45847.60     3677464.86      3723312.46
# 600608     3  246497.27     3723312.46      3969809.72
# 600609     3  168675.64     3969809.72      4138485.36
# 600610     3   42658.19     4138485.36      4181143.56
#
# [600611 rows x 4 columns]

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC

# %%
models=[]
results=[]
names=[]

# %%
models.append(('LR',LogisticRegression()))
models.append(('LDA',LinearDiscriminantAnalysis()))
models.append(('KNN',KNeighborsClassifier()))
models.append(('CART',DecisionTreeClassifier()))
models.append(('NB',GaussianNB()))
models.append(('SVM',SVC()))

# %%
models
# Out:
# [('LR', LogisticRegression()),
#  ('LDA', LinearDiscriminantAnalysis()),
#  ('KNN', KNeighborsClassifier()),
#  ('CART', DecisionTreeClassifier()),
#  ('NB', GaussianNB()),
#  ('SVM', SVC())]

# %%
from sklearn import model_selection
for name,model in models:
  kfold=model_selection.KFold(n_splits=10,random_state=7,shuffle=True)
  cv_results=model_selection.cross_val_score(model,x,y,cv=kfold,scoring='accuracy')
  results.append(cv_results)
  names.append(name)
  msg="%s: %f (%f)" %(name,cv_results.mean(),cv_results.std())
  print(msg)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning:
#
# lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning:
#
# lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#
# ...
